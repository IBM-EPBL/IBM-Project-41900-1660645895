# %% [markdown]
# <center><h2>Importing the Libraries</h2></center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <center><h2>Reading the Dataset</h2></center>

# %%
data = pd.read_csv("dataset/Admission_Predict.csv")

# %% [markdown]
# <center><h2>Analyse the Data</h2><center>

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.drop(["Serial No."],axis=1,inplace=True)
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %% [markdown]
# <center><h2>Handling Missing Values</h2></center>

# %%
data.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# <center><h2>Data Description</h2></center>

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# 50%      8.610000    1.000000          0.730000
# 75%      9.062500    1.000000          0.830000
# max      9.920000    1.000000          0.970000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %% [markdown]
# <center><h2>Data Visualisation</h2></center>

# %% [markdown]
# ###### UNIVARIATE ANALYSIS
# <hr style="height:1px;">

# %%
from scipy import stats

# %%
c=np.random.normal(loc=5,size=100,scale=2)

# %% [markdown]
# <small> HISTOGRAM </small>

# %%
sns.histplot(data["GRE Score"],color='orange')
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Count'>

# %%
sns.histplot(data["TOEFL Score"],color='violet')
# Out:
# <AxesSubplot:xlabel='TOEFL Score', ylabel='Count'>

# %%
sns.displot(data["University Rating"],color='indigo')

# %%
sns.boxplot(data["TOEFL Score"],color='brown')
# Out:
# C:\Users\Sandeshnair\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOEFL Score'>

# %% [markdown]
# <small> BOX PLOT </small>

# %%
sns.boxplot(x=data['University Rating'],color='pink')
# Out:
# <AxesSubplot:xlabel='University Rating'>

# %%
sns.histplot(data.CGPA,color="blue")
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Count'>

# %% [markdown]
# <small> COUNT PLOT </small>

# %%
sns.countplot(x=data['TOEFL Score'])
# Out:
# <AxesSubplot:xlabel='TOEFL Score', ylabel='count'>

# %% [markdown]
# ###### BIVARIATE ANALYSIS
# <hr style="height:1px;">

# %% [markdown]
# <small> BAR PLOT </small>

# %%
sns.barplot(x=data.SOP,y=data.CGPA)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %% [markdown]
# <small>LINEAR PLOT</small>

# %%
sns.lineplot(data["GRE Score"],data["SOP"], color='aqua')
# Out:
# C:\Users\Sandeshnair\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GRE Score', ylabel='SOP'>

# %%
sns.lineplot(x=data.SOP,y=data.CGPA, color='purple')
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %% [markdown]
# <small>SCATTER PLOT</small>

# %%
sns.scatterplot(x=data['TOEFL Score'],y=data['University Rating'],color='green')
# Out:
# <AxesSubplot:xlabel='TOEFL Score', ylabel='University Rating'>

# %% [markdown]
# <small>POINT PLOT</small>

# %%
sns.pointplot(x=data['SOP'],y=data['CGPA'],color='yellow')
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %% [markdown]
# <small>REG PLOT</small>

# %%
sns.regplot(x=data.CGPA,y=data['GRE Score'],color='Brown')
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='GRE Score'>

# %% [markdown]
# <small>RELPLOT</small>

# %%
sns.relplot(x="GRE Score",y="CGPA",data=data)

# %% [markdown]
# ###### Multivariate Analysis
# <hr style="height:1px;">

# %% [markdown]
# <small>PAIR PLOT</small>

# %%
sns.pairplot(data=data[["GRE Score","TOEFL Score","University Rating","SOP","CGPA","Research"]])

# %%
sns.pairplot(data=data[["GRE Score","TOEFL Score","University Rating","SOP","CGPA","Research"]],kind="kde")

# %% [markdown]
# <center><h2>SPLITTING DEPENDENT AND INDEPENDENT COLUMNS</h2></center>

# %%
X=data.drop(['Chance of Admit '],axis=1) #input data_set
y=data['Chance of Admit '] #output labels

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train[X_train.columns] = scaler.fit_transform(X_train[X_train.columns])
X_test[X_test.columns] = scaler.transform(X_test[X_test.columns])
X_train.head()
# Out:
#      GRE Score  TOEFL Score  University Rating   SOP   LOR       CGPA  \
# 384       1.00     0.750000               0.75  1.00  1.000  0.942308
# 306       0.66     0.642857               0.50  0.75  0.625  0.737179
# 2         0.52     0.428571               0.50  0.50  0.625  0.384615
# 93        0.22     0.178571               0.25  0.50  0.500  0.346154
# 39        0.34     0.571429               0.25  0.75  0.625  0.288462
#
#      Research
# 384       1.0
# 306       1.0
# 2         1.0
# 93        1.0
# 39        0.0

# %%
from sklearn.ensemble import GradientBoostingRegressor
rgr = GradientBoostingRegressor()
rgr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
rgr.score(X_test,y_test)
# Out:
# 0.6540244652433289

# %%
y_predict=rgr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
import numpy as np
print('Mean Absolute Error:', mean_absolute_error(y_test, y_predict))  
print('Mean Squared Error:', mean_squared_error(y_test, y_predict))  
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# Mean Absolute Error: 0.046004006710170395
# Mean Squared Error: 0.004088046918684826
# Root Mean Squared Error: 0.06393783636224193

# %%
y_train = (y_train>0.5)
y_test = (y_test>0.5)

# %%
from sklearn.linear_model._logistic import LogisticRegression

lore = LogisticRegression(random_state=0, max_iter=1000)

lr = lore.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print('Accuracy Score:', accuracy_score(y_test, y_pred))  
print('Recall Score:', recall_score(y_test, y_pred))  
print('ROC AUC Score:', roc_auc_score(y_test, y_pred))
print('Confussion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Accuracy Score: 0.9833333333333333
# Recall Score: 1.0
# ROC AUC Score: 0.5
# Confussion Matrix:
#  [[ 0  1]
#  [ 0 59]]

# %% [markdown]
# <center><h2>SAVING THE MODELS</h2></center>

# %%
import pickle
pickle.dump(rgr,open('university.pkl','wb'))
pickle.dump(rgr, open("university_percent.pkl", "wb"))
lr = pickle.load(open("university.pkl", "rb")) #logistic regression model
gd = pickle.load(open("university_percent.pkl", "rb")) #regression model
